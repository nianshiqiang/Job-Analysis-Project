# %%
import pandas as pd
import numpy as np
import re

# %%
class LiepinDataPreprocess:
    def __init__(self):
        pass
    
    def __general(self,df):
        df_new = df.drop(['发布网站','原始URL','薪资阶段','公司主页','专业要求','部门'],axis = 1)
        return df_new
    
    def __company_scale_yuchuli(self,x):
        if (x is not np.nan) and (x is not None):
            pattern = r"公司规模：(.+)人"
            match = re.findall(pattern,x)
            if len(match)!= 0:
                return match[0]
        #     有些记录为：公司地址：番禺节能科技园总部2号楼19层 
            else:
                return -1
            
    def company_scale_process(self,df):
        df['company_scale'] = df['公司规模'].apply(self.__company_scale_yuchuli)
        return df[['company_scale']]
    
    def __experience_yuchuli(self,x):
        if (x >= 1) and (x <= 3):
            return '1-3'
        elif x == 0:
            return '不限'
        elif (x > 3) and (x <= 5):
            return '3-5'
        elif (x >5) and (x <= 10):
            return '5-10'
        elif x > 10:
            return '10'
        
    def job_experience_process(self,df):
        df['new_work_experience'] = df['经验'].apply(lambda x :int(x[:-3]) if x[0] != '经' else 0)
        df['job_experience'] = df['new_work_experience'].apply(self.__experience_yuchuli)
        return df[['job_experience']]
    
#     工作地点（市）处理
    def __city_process(self,x):
        if (x is not np.nan) and (x is not None):
            pattern = r"(.+)-"
            if '-' in x:
                match = re.findall(pattern,x)
                return match[0]
            else :
                return x
        else:
            return str(-1)
#   工作地点（区）处理
    def __district_process(self,x):
        if (x is not np.nan) and (x is not None):
            pattern = r"-(.+)"
            match = re.findall(pattern,x)
            if len(match) != 0:
                return match[0]
            else :
                return str(-1)
        else :
            return str(-1)
        
    def workingplace_process(self,df):
        df['work_position'] = df['工作地点'].apply(self.__city_process)
        df['work_district'] = df['工作地点'].apply(self.__district_process)
        return df[['work_position','work_district']]
    
    def education_degree_process(self,df):
        df.loc[df['学历'] == '本科及以上','学历'] = '本科'
        df.loc[df['学历'] == '统招本科','学历'] = '本科'
        df.loc[df['学历'] == '大专及以上','学历'] = '大专'
        df.loc[df['学历'] == '硕士及以上','学历'] = '硕士'
        df.loc[df['学历'] == '学历不限','学历'] = '不限'
        df.loc[df['学历'] == '中专/中技及以上','学历'] = '中专'
        df_new = df.rename(columns = {'学历':'education_degree'})
        return df_new[['education_degree']]
    
    def publish_data_process(self,df):
        df['publish_date'] = df['发布日期'].apply(lambda x : x[:4]+'-'+x[5:7]+'-'+x[8:10] \
                                             if ((x is not np.nan) or (x is not None)) else str(-1) )  
        df['publish_time'] = np.nan
        return df[['publish_date','publish_time']]
#         最小工资处理
    def __min_salary(self,x):
        if ((x is not np.nan) and (x is not None)):
            pattern2 = r"(.+)-"
            match2 = re.findall(pattern2,str(x))
            if len(match2) != 0:
                return int(match2[0])
            elif '面议' in x:
                return -1
            else:
                return int(x)
        else:
            return -1
    def __max_salary(self,x):
        if ((x is not np.nan) and (x is not None)):
            pattern2 = r".-(.+)"
            match2 = re.findall(pattern2,str(x))
            if len(match2) != 0:
                return int(match2[0])
            elif '面议' in x:
                return -1
            else:
                return int(x)
        else:
            return -1   
#     salary处理 输入 原始数据的df，返回处理后的薪资相关特征
    def salary_process(self,df):
        df['salary_max'] = df['薪资'].apply(self.__max_salary)
        df['salary_min'] = df['薪资'].apply(self.__min_salary)
        df['salary_avg'] = (df['salary_max'] + df['salary_min']) / 2
        return df[['salary_max','salary_min','salary_avg']]
    def other_change(self,df):
        df_new = df.rename(columns = {'职位名称':'job_name',
                                '工作性质':'job_nature',
                                '招聘人数':'demand_number',
                                '职位诱惑':'welfare',
                                '岗位介绍':'job_description',
                                '公司名称':'company_name',
                                '公司行业':'company_industry',
                                 '公司性质':'company_nature'
                                })
        
        return df_new[['job_name','job_nature','demand_number','welfare','job_description','company_name','company_industry','company_nature']]
        
    
    def data_process(self,df):
        df = self.__general(df)
        scale = self.company_scale_process(df)
        experience = self.job_experience_process(df)
        place = self.workingplace_process(df)
        edu = self.education_degree_process(df)
        publish_date = self.publish_data_process(df)
        salary = self.salary_process(df)
        other = self.other_change(df)
        final = pd.concat([other,scale,experience,place,edu,publish_date,salary],axis = 1)
        return final

# %%
data = pd.read_csv('./data/jobInfo_liepin.csv')

# %%
l = LiepinDataPreprocess()

# %%
l.company_scale_process(data).head()
# Out:
#   company_scale
# 0       100-499
# 1         10000
# 2       100-499
# 3       100-499
# 4       100-499

# %%
l.data_process(data)
# Out:
#                       job_name  job_nature  demand_number  \
# 0                      资深数据挖掘岗         NaN            NaN
# 1           高级数据挖掘工程师-邮件事业部239         NaN            NaN
# 2                  资深爬虫工程师/架构师         NaN            NaN
# 3                      爬虫开发工程师         NaN            NaN
# 4              爬虫开发工程师/采集器工...         NaN            NaN
# 5                Python数据爬虫工程师         NaN            NaN
# 6               数据抓取及处理（高级）工程师         NaN            NaN
# 7                       Java爬虫         NaN            NaN
# 8                      资深爬虫架构师         NaN            NaN
# 9                    政务大数据项目经理         NaN            NaN
# 10            大数据风控建模工程师/高级工程师         NaN            NaN
# 11       Hbase Mapreduce 开发工程师         NaN            NaN
# 12          Hbase高级开发工程师035187         NaN            NaN
# 13     大数据架构师（Hbase方向）【大数据研发部】         NaN            NaN
# 14           大数据开发工程师（HBase方向）         NaN            NaN
# 15            外卖业务商业分析师 – 渠...         NaN            NaN
# 16               党建商业分析员（电力行业）         NaN            NaN
# 17                     机器学习工程师         NaN            NaN
# 18                  大数据架构师（深圳）         NaN            NaN
# 19                  大数据平台研发工程师         NaN            NaN
# 20                    大数据平台架构师         NaN            NaN
# 21                    大数据运维工程师         NaN            NaN
# 22                大数据平台开发高级工程师         NaN            NaN
# 23                     大数据产品经理         NaN            NaN
# 24                    大数据BI工程师         NaN            NaN
# 25      0311AD-产品设计岗（大数据体系建立方向         NaN            NaN
# 26                    大数据开发工程师         NaN            NaN
# 27                 大数据方向高级产品经理         NaN            NaN
# 28                      大数据架构师         NaN            NaN
# 29                 高级产品经理(大数据)         NaN            NaN
# ...                        ...         ...            ...
# 11308                   流程管理专员         NaN            NaN
# 11309                  CRM分析经理         NaN            NaN
# 11310                     运营管理         NaN            NaN
# 11311       销售运营（客户资源管理方向，大数据）         NaN            NaN
# 11312                   商城运营专家         NaN            NaN
# 11313                  产品经理/总监         NaN            NaN
# 11314           DC服务助理（外高桥SDC）         NaN            NaN
# 11315                  互联网产品经理         NaN            NaN
# 11316              产品总监（虚拟信用卡）         NaN            NaN
# 11317                   高级产品经理         NaN            NaN
# 11318                     产品经理         NaN            NaN
# 11319                   ASO优化师         NaN            NaN
# 11320                  新媒体运营专员         NaN            NaN
# 11321                    微商操盘手         NaN            NaN
# 11322                    微商操盘手         NaN            NaN
# 11323                    新媒体运营         NaN            NaN
# 11324            产品运营专员/平台运营专员         NaN            NaN
# 11325                   资深文案策划         NaN            NaN
# 11326                   棋牌游戏运营         NaN            NaN
# 11327                   棋牌游戏运营         NaN            NaN
# 11328                   运营策划主管         NaN            NaN
# 11329                  运营支持部部长         NaN            NaN
# 11330                   市场运营总监         NaN            NaN
# 11331               运营经理(1703)         NaN            NaN
# 11332                     运营专员         NaN            NaN
# 11333                   数据分析主管         NaN            NaN
# 11334                 数字媒体营销经理         NaN            NaN
# 11335                     内容运营         NaN            NaN
# 11336                  呼叫中心负责人         NaN            NaN
# 11337                JL—产品运营经理         NaN            NaN
#
#                                                  welfare  \
# 0                          领导好,五险一金,发展空间大,绩效奖金,带薪年假,数据驱动
# 1                                                    NaN
# 2      五险一金,技能培训,绩效奖金,弹性工作,节日礼物,团队聚餐,扁平管理,年底双薪,带薪年假,领...
# 3                                    领导好,技能培训,岗位晋升,发展空间大
# 4                                   领导好,技能培训,岗位晋升,发展空间大
# 5                                   股票期权,弹性工作,发展空间大,绩效奖金
# 6      六险一金,弹性工作,免费三餐,租房补贴,带薪休假,休闲下午茶,扁平管理,健身瑜伽,过亿用户,...
# 7                               大牛领导,带薪年假,弹性工作,五险一金,扁平管理
# 8      五险一金,技能培训,绩效奖金,弹性工作,节日礼物,扁平管理,带薪年假,领导好,优秀员工奖,岗...
# 9                                    带薪年假,午餐补助,五险一金,交通补助
# 10     带薪年假,通讯津贴,定期体检,年度旅游,节日礼物,领导好,扁平管理,上市公司,发展空间大,休...
# 11                       公司规模大,带薪年假,五险一金,节假日福利,节日礼物,定期体检
# 12                                                    班车
# 13     午餐补助,弹性工作,定期体检,五险一金,500强,公司规模大,上市公司,发展空间大,领导好,...
# 14      发展空间大,公司规模大,管理规范,16薪,大牛多,福利好,带薪年假,绩效奖金,定期体检,伙食超好
# 15                                  领导好,技能培训,岗位晋升,发展空间大
# 16     五险一金,定期体检,绩效奖金,通讯津贴,无风险事业平台,无发展瓶颈,打造个人市场品牌,丰厚收...
# 17                             五险一金,带薪年假,弹性工作,发展空间大,扁平管理
# 18                            银行好福利,带薪年假,定期体检,年度旅游,发展空间大
# 19                                   领导好,扁平管理,五险一金,超高年终奖
# 20              绩效奖金,年底双薪,扁平管理,领导好,岗位晋升,发展空间大,公司规模大,带薪年假
# 21                                  领导好,技能培训,岗位晋升,发展空间大
# 22     带薪年假,交通补助,午餐补助,定期体检,五险一金,节日礼物,管理规范,岗位晋升,500强,子...
# 23                                            午餐补助,发展空间大
# 24     年底双薪,绩效奖金,带薪年假,交通补助,通讯津贴,午餐补助,定期体检,弹性工作,年度旅游,节...
# 25                              五险一金,年底双薪,绩效奖金,带薪年假,定期体检
# 26                                            午餐补助,发展空间大
# 27     绩效奖金,带薪年假,五险一金,交通补助,午餐补助,岗位晋升,公司规模大,节日礼物,定期体检,...
# 28                         节日礼物,年度旅游,定期体检,五险一金,通讯津贴,午餐补助
# 29     绩效奖金,带薪年假,五险一金,交通补助,午餐补助,岗位晋升,公司规模大,节日礼物,定期体检,...
# ...                                                  ...
# 11308             年底双薪,定期体检,年度旅游,节日礼物,领导好,管理规范,技能培训,岗位晋升
# 11309                      绩效奖金,午餐补助,定期体检,弹性工作,免费班车,扁平管理
# 11310  绩效奖金,带薪年假,定期体检,年度旅游,节日礼物,领导好,管理规范,五险一金,公司规模大,休闲餐点
# 11311    年底双薪,绩效奖金,带薪年假,定期体检,弹性工作,管理规范,扁平管理,发展空间大,一年多次调薪
# 11312                           大牛领导,带薪年假,弹性工作,五险一金,扁平管理
# 11313  年底双薪,股票期权,绩效奖金,带薪年假,交通补助,通讯津贴,节日礼物,领导好,发展空间大,车...
# 11314  领导好,技能培训,岗位晋升,发展空间大,绩效奖金,带薪年假,交通补助,通讯津贴,五险一金,节...
# 11315  公司规模大,发展空间大,五险一金,带薪年假,交通补助,通讯津贴,午餐补助,定期体检,管理规范...
# 11316      年底双薪,绩效奖金,带薪年假,弹性工作,节日礼物,上市公司,五险一金,岗位晋升,发展空间大
# 11317                  带薪年假,扁平管理,领导好,午餐补助,弹性工作,五险一金,休闲餐点
# 11318                  带薪年假,扁平管理,领导好,午餐补助,弹性工作,五险一金,休闲餐点
# 11319                            弹性工作,扁平管理,领导好,五险一金,技能培训
# 11320  发展空间大,弹性工作,定期体检,五险一金,技能培训,领导好,带薪年假,午餐补助,通讯津贴,团...
# 11321                                领导好,技能培训,岗位晋升,发展空间大
# 11322  五险一金,午餐补助,技能培训,带薪年假,节日礼物,岗位晋升,绩效奖金,年底双薪,公司规模大,...
# 11323                           带薪年假,弹性工作,五险一金,岗位晋升,节日福利
# 11324                  年底双薪,带薪年假,五险一金,节日礼物,年度旅游,领导好,双休加班
# 11325  带薪年假,年底双薪,午餐补助,定期体检,弹性工作,年度旅游,节日礼物,领导好,扁平管理,五险...
# 11326  免费班车,团队聚餐,定期体检,节日福利,花园式办公,员工宿舍,周末双休,优秀员工奖,技能培训...
# 11327  免费班车,团队聚餐,定期体检,节日福利,花园式办公,员工宿舍,周末双休,优秀员工奖,技能培训...
# 11328                                五险一金,绩效奖金,带薪年假,定期体检
# 11329  管理规范,五险一金,定期体检,通讯津贴,公司规模大,技能培训,岗位晋升,发展空间大,绩效奖金...
# 11330                          五险一金,带薪年假,发展空间大,技能培训,岗位晋升
# 11331           年底双薪,带薪年假,五险一金,节日礼物,定期体检,领导好,公司规模大,发展空间大
# 11332  绩效奖金,带薪年假,交通补助,午餐补助,定期体检,弹性工作,节日礼物,领导好,五险一金,生育...
# 11333                               五险一金,带薪年假,岗位晋升,发展空间大
# 11334                                        平台大,薪酬高,晋升快
# 11335   带薪年假,扁平管理,五险一金,休闲餐点,团队年轻有活力,发展空间大,年底双薪,绩效奖金,年度旅游
# 11336                通讯津贴,定期体检,公司规模大,年终绩效,五险一金,带薪年假,绩效奖金
# 11337                                 带薪年假,节日礼物,领导好,扁平管理
#
#                                          job_description         company_name  \
# 0      岗位职责：\n1、负责针对金融贷款客户开展各类常规性分析和专题性分析、市场营销模型的生命周期...       深圳中兴飞贷金融科技有限公司
# 1      工作职责：\n1、邮箱产品海量日志的统计分析；\n2、产品业务数据分析平台的设计和开发；\n...                 网易集团
# 2      岗位职责：\n1、负责爬虫系统架构设计与开发，需要爬取全球泛服饰类数据，并且做到实施更新；\...                 深绘智能
# 3      岗位职责：\n1、参与爬虫及相关辅助系统的编程开发；\n2、参与高并发海量数据系统的设计开发...                 深绘智能
# 4      岗位职责：\n1.负责设计和开发分布式爬虫程序，对互联网相关信息进行抓取；\n2.实现文本、...       广州市云润大数据服务有限公司
# 5      职责描述：\n    1. 负责产品需求分析，对产品的原始需求做总结分析\n    2. 负...       金车信息科技(上海)有限公司
# 6      工作职责：\n1、负责商业化相关的数据抓取和清洗工作；\n2、推进抓取架构的完善，不断提升系...                 今日头条
# 7      工作职责：\n1、负责泉眼分布式爬虫设计和开发；\n2、负责网页数据抽取、数据清洗和数据挖掘...                   泉眼
# 8      岗位职责：\n1、负责爬虫系统架构设计与开发，需要爬取全球泛服饰类数据，并且做到实施更新；\...                 深绘智能
# 9      岗位职责：\n1、负责组织制定面向行业客户需求项目（包括大数据项目、集成项目及服务项目）的咨...       绿欣科技发展(北京)有限公司
# 10     职责描述：\n1、参与外部数据采购、大数据风控建模、风险策略自动化等大数据风控体系建设相关工...                 诺亚控股
# 11     岗位职责：\n1. 负责大数据管理平台中各模块管理和功能设计；\n2. 负责大数据平台的数据...             软通动力-GBG
# 12     职责描述：\n1、Hbase/ Kylin等大数据集群的规划、搭建、优化以及监控维护, Hb...               京东金融集团
# 13     职责描述：\n1、负责京东大规模HBase集群的高可用和稳定性建设；\n2、支持业务需求，深...                   京东
# 14     岗位职责：\n1. 负责网易游戏 HBase 集群的规划、设计和建设；\n2. 对接业务需求...                 网易集团
# 15     岗位职责：\n1、梳理美团外卖内部渠道管理业务流程，实现流程优化\n2、结合现状分析、蓝图设...                 美团点评
# 16     职位亮点：完善知识体系、丰厚收入、无发展瓶颈、MBA培训、多通道发展、专家分享、扁平管理\n...                 中大咨询
# 17     岗位职责：\n1) 基于用户家庭场景数据，包括各类智能设备、传感器和外部数据，通过机器学习技...                  和而泰
# 18     岗位职责：\n1、参与公司自主数据产品设计、开发工作，根据需求，完成系统的概要设计、详细设计...       深圳平安综合金融服务有限公司
# 19     职责描述：\n岗位职责\n1. 负责公司大数据平台的搭建和海量数据处理；\n2. 负责数据采...         深圳小鹅网络技术有限公司
# 20     职责描述：\n1、负责基于Hadoop/Spark等生态系统的大数据平台的架构设计、技术选型...       百丽电子商务(上海)有限公司
# 21     1. 负责公司产品的技术支持、安装调试、客户使用培训及相关硬件的安装调试；\n2. 就项目实...  杭州三汇数字信息技术有限公司天津分公司
# 22     工作部门：信息技术中心/数据分析与洞见部\n工作职责：\n1. 参与或负责数据仓库、或大数据...    中国太平洋保险(集团)股份有限公司
# 23     职责描述：\n1、负责大数据平台的产品规划设计并推动技术团队将产品落地\n2、负责精细化运营...       上海赛可出行科技服务有限公司
# 24     职责描述：\n? 根据公司业务需求，基于大数据平台完成数据落地，整合，计算等任务。\n? 参...                 卓望公司
# 25     工作职责：\n1 、负责公司智能培训产品模块设计，包括概念设计、产品规划方案、需求提交及检视...                 平安财险
# 26     职责描述：\n1、搭建基于Hadoop/Spark的数据挖掘体系和大数据分析系统架构；\n2...       上海赛可出行科技服务有限公司
# 27     岗位职责：\n1、负责用户特征数据挖掘、分析、应用，指导业务精细化运营，负责大数据分析平台的...      北京八月瓜知识产权代理有限公司
# 28     岗位职责：\n1.能够带领技术人员基于hadoop平台进行海量数据应用系统开发；\n2.负责...         北京东方金信科技有限公司
# 29     岗位职责：\n1、负责用户特征数据挖掘、分析、应用，指导业务精细化运营，负责大数据分析平台的...      北京八月瓜知识产权代理有限公司
# ...                                                  ...                  ...
# 11308  岗位职责:\n1、收集流程优化需求，提出流程优化建议；\n2、参与各部门流程梳理和优化工作；...          福建省三福百货有限公司
# 11309  职责描述：\n1.从事电商CRM分析1-2年以上，对电商CRM运营数据进行监控分析，根据数据...                 丽人丽妆
# 11310  职责描述：\n1.负责建立与完善运营数据报表体系；\n2.日常业务数据的收集、整理、统计和分...   红上诚诚(上海)商务信息咨询有限公司
# 11311  岗位职责：\n1，客户资源名单优化，信息完善，无效清洗，日常增删改查支持\n4，负责销售体系...              patsnap
# 11312  工作职责:\n1、制定销售目标和运营目标，对项目的PV、销量、跳出率、地域分布、转化率、用户...                   泉眼
# 11313  职位描述：\n1、负责产品的市场调研、竞品分析、需求分析、产品体验、数据分析、项目推动；\n...        烯旺新材料科技股份有限公司
# 11314  职责描述：\n1.\t负责为用户参观数据中心提供中英文讲解工作。\n2.\t负责收集整理数据...                 信天通信
# 11315  职位概述：\n  负责项目产品对接，包括但不仅限于网站、APP、专题页面等规划。参与并规划产...     三平伟业(北京)投资管理有限公司
# 11316  职责描述：\n1、 全面负责公司创新产品架构设计，深刻了解行业信息与走向，负责产品短期，中短...                 国美金控
# 11317  岗位职责：\n1.负责公司智慧健康云平台（SAAS模式）后端核心业务的需求分析、产品规划和产...                 健科云网
# 11318  岗位职责：\n1.负责后端核心业务的需求分析、产品规划和产品设计，搭建后台系统，对系统效率、...                 健科云网
# 11319  职责描述：\n1、针对公司产品制定相应ASO策略，并负责跟进过程并对结果负责；\n3、负责公...         北京清众教育科技有限公司
# 11320  职责描述：\n1、负责官方网站、微博、微信、头条等新媒体平台的内容推广，熟悉相关新媒体资源，...         北京微卓科技股份有限公司
# 11321  岗位要求\n1、负责微商前期起盘准备工作，包括熟悉微商系统、选品、品牌定位、市场分析等各个环...                 赛维网络
# 11322  岗位要求\n1、负责微商前期起盘准备工作，包括熟悉微商系统、选品、品牌定位、市场分析等各个环...                 赛维网络
# 11323  新媒体运营\n岗位职责：\n1.负责微信公众平台的运营，包括日常运营管理，内容更新等；\n2...    蓝海健康云智(北京)大数据有限公司
# 11324  职责描述：\n1.负责B2B平台的商品商品管理，订单管理，会员管理维护；\n2.负责商品类目...         上海唐狮文化传播有限公司
# 11325  职责描述：\n1、负责公司日常传播的宣传资料和相关活动文案撰写；\n2、负责新媒体、社会化媒...         上海哈希信息科技有限公司
# 11326  岗位职责:棋牌游戏的运营内容设计，用户管理，市场营销，数据分析；\n规划运营，推动运营工作，...         海南英立科技开发有限公司
# 11327  岗位职责:棋牌游戏的运营内容设计，用户管理，市场营销，数据分析；\n规划运营，推动运营工作，...         海南英立科技开发有限公司
# 11328  岗位职责：\n1、负责板块内分省运营热点的选择，重点页面的选题，重点位置图文的更新，常规专题...     中投视讯文化传媒(上海)有限公司
# 11329  工作职责：\n1、建立集团运营统计体系并不断完善（包括制度、指标、流程及组织保障等）；\n2...             linuocom
# 11330  工作内容：\n1、负责针对用户、产品特点和市场状况制定运营战略规划，媒体宣传、市场推广和渠道...         上海天坊信息科技有限公司
# 11331  岗位职责：\n1、建设运营专科医联体样板，维护客户及用户关系\n2、定期组织召开会议及培训，...       心医国际数字医疗系统有限公司
# 11332  岗位职责:\n1、负责完成每月指定游戏项目业绩指标；\n2、游戏运营项目的推广计划和预算的制...         海南祺曜互动娱乐有限公司
# 11333  职责描述：1、了解公司业务，并根据需要定期或者不定期统计收集各类数据，分析业务运营数据并确保...         中联金控资产管理有限公司
# 11334  此岗位汇报上级为外籍人士，英语为工作语言\n工作职责：\n1、制定新媒体推广方案及计划，编制...               四达软件北京
# 11335  岗位职责：\n1、把握产品定位，挖掘音乐产品卖点做内容运营；\n2、负责APP音乐平台的专题...        深圳市云动创想科技有限公司
# 11336  岗位职责：\n1、 全面负责呼叫中心团队建设与管理工作；\n2、 负责项目的整体运营与管理，...         云南俊发物业服务有限公司
# 11337  工作内容：\n1. 围绕各条线业务场景，做好核心指标的监测，能从监测数据中发现问题，精确定位...                 伯乔金融
#
#          company_industry  company_nature company_scale job_experience  \
# 0             基金/证券/期货/投资             NaN       100-499            3-5
# 1          互联网/移动互联网/电子商务             NaN         10000            3-5
# 2          互联网/移动互联网/电子商务             NaN       100-499            1-3
# 3          互联网/移动互联网/电子商务             NaN       100-499             不限
# 4          互联网/移动互联网/电子商务             NaN       100-499            1-3
# 5          互联网/移动互联网/电子商务             NaN          1-49            1-3
# 6          互联网/移动互联网/电子商务             NaN         10000            1-3
# 7          互联网/移动互联网/电子商务             NaN     1000-2000            3-5
# 8          互联网/移动互联网/电子商务             NaN       100-499            1-3
# 9          互联网/移动互联网/电子商务             NaN       100-499            3-5
# 10            基金/证券/期货/投资             NaN     2000-5000            1-3
# 11              IT服务/系统集成             NaN         10000            3-5
# 12            基金/证券/期货/投资             NaN     2000-5000            3-5
# 13         互联网/移动互联网/电子商务             NaN         10000            3-5
# 14         互联网/移动互联网/电子商务             NaN         10000            1-3
# 15         互联网/移动互联网/电子商务             NaN         10000            1-3
# 16     专业服务(咨询/财会/法律/翻...             NaN       500-999            1-3
# 17         互联网/移动互联网/电子商务             NaN     1000-2000            1-3
# 18            基金/证券/期货/投资             NaN         10000            3-5
# 19         互联网/移动互联网/电子商务             NaN       100-499            1-3
# 20         互联网/移动互联网/电子商务             NaN     2000-5000            1-3
# 21                  计算机软件             NaN     1000-2000            1-3
# 22                     保险             NaN     1000-2000            1-3
# 23         互联网/移动互联网/电子商务             NaN          1-49            1-3
# 24         互联网/移动互联网/电子商务             NaN     2000-5000            1-3
# 25                     保险             NaN         10000            1-3
# 26         互联网/移动互联网/电子商务             NaN          1-49            1-3
# 27     专业服务(咨询/财会/法律/翻...             NaN       100-499            3-5
# 28                  计算机软件             NaN       100-499            3-5
# 29     专业服务(咨询/财会/法律/翻...             NaN       100-499            3-5
# ...                   ...             ...           ...            ...
# 11308          服装服饰/纺织/皮革             NaN         10000            1-3
# 11309      互联网/移动互联网/电子商务             NaN       500-999             不限
# 11310         基金/证券/期货/投资             NaN    5000-10000            1-3
# 11311      互联网/移动互联网/电子商务             NaN       500-999            1-3
# 11312      互联网/移动互联网/电子商务             NaN     1000-2000            3-5
# 11313       医疗/保健/美容/卫生服务             NaN       100-499            1-3
# 11314        通信(设备/运营/增值)             NaN       100-499             不限
# 11315         基金/证券/期货/投资             NaN       500-999             不限
# 11316         基金/证券/期货/投资             NaN     2000-5000           5-10
# 11317      互联网/移动互联网/电子商务             NaN       100-499            3-5
# 11318      互联网/移动互联网/电子商务             NaN       100-499            3-5
# 11319      教育/培训/学术/科研/院校             NaN         50-99            1-3
# 11320      互联网/移动互联网/电子商务             NaN       100-499            1-3
# 11321      互联网/移动互联网/电子商务             NaN     2000-5000            1-3
# 11322      互联网/移动互联网/电子商务             NaN     2000-5000            1-3
# 11323      互联网/移动互联网/电子商务             NaN         50-99            1-3
# 11324       广告/公关/市场推广/会展             NaN          1-49            1-3
# 11325      互联网/移动互联网/电子商务             NaN         50-99            1-3
# 11326                网络游戏             NaN       100-499            1-3
# 11327                网络游戏             NaN       100-499            1-3
# 11328      互联网/移动互联网/电子商务             NaN       100-499            1-3
# 11329           能源(电力/水利)             NaN    5000-10000            1-3
# 11330               计算机软件             NaN       100-499            3-5
# 11331               计算机软件             NaN       500-999            1-3
# 11332                网络游戏             NaN       100-499            1-3
# 11333         基金/证券/期货/投资             NaN       100-499            1-3
# 11334        通信(设备/运营/增值)             NaN     2000-5000             不限
# 11335       电子技术/半导体/集成电路             NaN       100-499            1-3
# 11336   房地产服务(物业管理/地产经...             NaN     2000-5000            1-3
# 11337      互联网/移动互联网/电子商务             NaN         50-99            1-3
#
#       work_position work_district education_degree publish_date  publish_time  \
# 0                深圳            -1               本科   2018-07-13           NaN
# 1                广州            -1               不限   2018-07-14           NaN
# 2                杭州            -1               本科   2018-07-14           NaN
# 3                成都           双流县               不限   2018-07-14           NaN
# 4                广州            -1               大专   2018-07-13           NaN
# 5                上海            -1               本科   2018-07-14           NaN
# 6                北京           海淀区               本科   2018-07-13           NaN
# 7                上海           黄浦区               本科   2018-07-13           NaN
# 8                成都           双流县               本科   2018-07-14           NaN
# 9                成都           崇州市               本科   2018-07-13           NaN
# 10               上海           杨浦区               本科   2018-07-13           NaN
# 11               北京            -1               本科   2018-07-13           NaN
# 12               北京            -1               本科   2018-07-13           NaN
# 13               北京            -1               本科   2018-07-10           NaN
# 14               广州           天河区               本科   2018-07-11           NaN
# 15               北京            -1               本科   2018-07-13           NaN
# 16               广州            -1               本科   2018-07-13           NaN
# 17               深圳            -1               硕士   2018-07-13           NaN
# 18               深圳           罗湖区               本科   2018-07-13           NaN
# 19               深圳            -1               本科   2018-07-13           NaN
# 20               深圳           南山区               大专   2018-07-13           NaN
# 21               天津            -1               大专   2018-07-13           NaN
# 22               上海            -1               本科   2018-07-13           NaN
# 23               上海            -1               本科   2018-07-13           NaN
# 24               杭州           拱墅区               大专   2018-07-13           NaN
# 25               深圳            -1               不限   2018-07-13           NaN
# 26               上海            -1               本科   2018-07-13           NaN
# 27               北京           丰台区               本科   2018-07-13           NaN
# 28               北京           东城区               本科   2018-07-13           NaN
# 29               北京           丰台区               本科   2018-07-13           NaN
# ...             ...           ...              ...          ...           ...
# 11308            福州            -1               不限   2018-07-13           NaN
# 11309            上海            -1               本科   2018-07-13           NaN
# 11310            上海           黄浦区               本科   2018-07-13           NaN
# 11311            上海           闸北区               本科   2018-07-13           NaN
# 11312            上海           黄浦区               本科   2018-07-13           NaN
# 11313            深圳            -1               本科   2018-07-13           NaN
# 11314            上海            -1               不限   2018-07-13           NaN
# 11315            郑州            -1               本科   2018-07-13           NaN
# 11316            北京           朝阳区               本科   2018-07-12           NaN
# 11317            北京            -1               本科   2018-07-13           NaN
# 11318            北京            -1               本科   2018-07-13           NaN
# 11319            北京           海淀区               本科   2018-07-12           NaN
# 11320            北京            -1               本科   2018-07-13           NaN
# 11321            深圳           龙岗区               大专   2018-07-13           NaN
# 11322            深圳            -1               大专   2018-07-13           NaN
# 11323            北京            -1               大专   2018-07-13           NaN
# 11324            上海           徐汇区               大专   2018-07-13           NaN
# 11325            上海           徐汇区               本科   2018-07-13           NaN
# 11326            成都            -1               本科   2018-07-13           NaN
# 11327            海口            -1               本科   2018-07-13           NaN
# 11328            昆明            -1               大专   2018-07-13           NaN
# 11329            济南            -1               本科   2018-07-13           NaN
# 11330            上海            -1               本科   2018-07-13           NaN
# 11331            上海            -1               不限   2018-07-12           NaN
# 11332            广州            -1               大专   2018-07-13           NaN
# 11333            北京            -1               大专   2018-07-13           NaN
# 11334            北京           大兴区               本科   2018-07-13           NaN
# 11335            深圳            -1               本科   2018-07-13           NaN
# 11336            昆明            -1               大专   2018-07-13           NaN
# 11337            上海            -1               不限   2018-07-13           NaN
#
#        salary_max  salary_min  salary_avg
# 0          750000      380000    565000.0
# 1              -1          -1        -1.0
# 2          360000      180000    270000.0
# 3          360000      180000    270000.0
# 4          140000       70000    105000.0
# 5          300000      180000    240000.0
# 6              -1          -1        -1.0
# 7          900000      450000    675000.0
# 8          360000      180000    270000.0
# 9          300000      180000    240000.0
# 10             -1          -1        -1.0
# 11         260000      180000    220000.0
# 12             -1          -1        -1.0
# 13         840000      480000    660000.0
# 14             -1          -1        -1.0
# 15         440000      300000    370000.0
# 16         120000       70000     95000.0
# 17         480000      180000    330000.0
# 18        1020000      510000    765000.0
# 19         240000      120000    180000.0
# 20         900000      540000    720000.0
# 21         100000       50000     75000.0
# 22         350000      140000    245000.0
# 23             -1          -1        -1.0
# 24         310000      190000    250000.0
# 25         340000      250000    295000.0
# 26             -1          -1        -1.0
# 27         480000      420000    450000.0
# 28         480000      240000    360000.0
# 29         480000      420000    450000.0
# ...           ...         ...         ...
# 11308       80000       50000     65000.0
# 11309      220000      180000    200000.0
# 11310      100000       70000     85000.0
# 11311      180000      100000    140000.0
# 11312          -1          -1        -1.0
# 11313      260000      130000    195000.0
# 11314      140000      100000    120000.0
# 11315      360000      180000    270000.0
# 11316      700000      560000    630000.0
# 11317      360000      240000    300000.0
# 11318      360000      240000    300000.0
# 11319      120000      100000    110000.0
# 11320      100000       70000     85000.0
# 11321      960000      600000    780000.0
# 11322      330000      200000    265000.0
# 11323      120000      100000    110000.0
# 11324      100000       60000     80000.0
# 11325          -1          -1        -1.0
# 11326      600000      240000    420000.0
# 11327      600000      240000    420000.0
# 11328      100000       70000     85000.0
# 11329      180000      120000    150000.0
# 11330      360000      240000    300000.0
# 11331      190000      140000    165000.0
# 11332      100000       50000     75000.0
# 11333      120000      100000    110000.0
# 11334          -1          -1        -1.0
# 11335      120000       70000     95000.0
# 11336      100000       70000     85000.0
# 11337      180000      120000    150000.0
#
# [11338 rows x 18 columns]

# %%
l.salary_process(data)
# Out:
#        salary_max  salary_min  salary_avg
# 0          750000      380000    565000.0
# 1              -1          -1        -1.0
# 2          360000      180000    270000.0
# 3          360000      180000    270000.0
# 4          140000       70000    105000.0
# 5          300000      180000    240000.0
# 6              -1          -1        -1.0
# 7          900000      450000    675000.0
# 8          360000      180000    270000.0
# 9          300000      180000    240000.0
# 10             -1          -1        -1.0
# 11         260000      180000    220000.0
# 12             -1          -1        -1.0
# 13         840000      480000    660000.0
# 14             -1          -1        -1.0
# 15         440000      300000    370000.0
# 16         120000       70000     95000.0
# 17         480000      180000    330000.0
# 18        1020000      510000    765000.0
# 19         240000      120000    180000.0
# 20         900000      540000    720000.0
# 21         100000       50000     75000.0
# 22         350000      140000    245000.0
# 23             -1          -1        -1.0
# 24         310000      190000    250000.0
# 25         340000      250000    295000.0
# 26             -1          -1        -1.0
# 27         480000      420000    450000.0
# 28         480000      240000    360000.0
# 29         480000      420000    450000.0
# ...           ...         ...         ...
# 11308       80000       50000     65000.0
# 11309      220000      180000    200000.0
# 11310      100000       70000     85000.0
# 11311      180000      100000    140000.0
# 11312          -1          -1        -1.0
# 11313      260000      130000    195000.0
# 11314      140000      100000    120000.0
# 11315      360000      180000    270000.0
# 11316      700000      560000    630000.0
# 11317      360000      240000    300000.0
# 11318      360000      240000    300000.0
# 11319      120000      100000    110000.0
# 11320      100000       70000     85000.0
# 11321      960000      600000    780000.0
# 11322      330000      200000    265000.0
# 11323      120000      100000    110000.0
# 11324      100000       60000     80000.0
# 11325          -1          -1        -1.0
# 11326      600000      240000    420000.0
# 11327      600000      240000    420000.0
# 11328      100000       70000     85000.0
# 11329      180000      120000    150000.0
# 11330      360000      240000    300000.0
# 11331      190000      140000    165000.0
# 11332      100000       50000     75000.0
# 11333      120000      100000    110000.0
# 11334          -1          -1        -1.0
# 11335      120000       70000     95000.0
# 11336      100000       70000     85000.0
# 11337      180000      120000    150000.0
#
# [11338 rows x 3 columns]
